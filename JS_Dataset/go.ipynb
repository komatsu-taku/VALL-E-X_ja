# %%
import gdown
import zipfile
import os
import py7zr
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1xdrdvk6uk3OW9kAb78dWzY_Kv7sneqNF
# From (redirected): https://drive.google.com/uc?id=1xdrdvk6uk3OW9kAb78dWzY_Kv7sneqNF&confirm=t&uuid=7935c7f4-aee6-41c3-9875-e7c802eb583e
# To: c:\Users\BBS\code\VALL-E-X-Trainer-by-CustomData\JS_Dataset\small_tune.zip
# 100%|██████████| 149M/149M [00:04<00:00, 33.6MB/s]

# %%
! gdown --id 1Fok35dUHJrTt53XqK5h2L7JIe6Iq9Y_O

# %%
os.makedirs('JS_Dataset',exist_ok=True)
with py7zr.SevenZipFile('train_tune.7z', mode='r') as z:
    z.extractall('JS_Dataset')
# Out:
# Downloading...
# From: https://drive.google.com/file/d/1Fok35dUHJrTt53XqK5h2L7JIe6Iq9Y_O
# To: c:\Users\BBS\code\VALL-E-X-Trainer-by-CustomData\JS_Dataset\train_tune.7z
# 83.7kB [00:00, ?B/s]
# ---------------------------------------------------------------------------
# Bad7zFile                                 Traceback (most recent call last)
# c:\Users\BBS\code\VALL-E-X-Trainer-by-CustomData\JS_Dataset\go.ipynb Cell 2 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/BBS/code/VALL-E-X-Trainer-by-CustomData/JS_Dataset/go.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> gdown.download(url, output, quiet=False, fuzzy=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/BBS/code/VALL-E-X-Trainer-by-CustomData/JS_Dataset/go.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> os.makedirs('JS_Dataset',exist_ok=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/BBS/code/VALL-E-X-Trainer-by-CustomData/JS_Dataset/go.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> with py7zr.SevenZipFile(output, mode='r') as z:
# ...

# %%
! gdown --id 1y2Ub_KjGSo1qIFOVFfisGxsxPip9lt_6
# Out:
# C:\Users\BBS\miniconda3\lib\site-packages\gdown\cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1y2Ub_KjGSo1qIFOVFfisGxsxPip9lt_6
# From (redirected): https://drive.google.com/uc?id=1y2Ub_KjGSo1qIFOVFfisGxsxPip9lt_6&confirm=t&uuid=5352c53c-3eeb-4878-9c88-60649d6867ce
# To: c:\Users\BBS\code\VALL-E-X-Trainer-by-CustomData\JS_Dataset\valid_tune.7z
#
#   0%|          | 0.00/614M [00:00<?, ?B/s]
#   1%|          | 3.67M/614M [00:00<00:17, 35.4MB/s]
#   1%|          | 7.34M/614M [00:00<00:17, 35.6MB/s]
#   2%|▏         | 11.5M/614M [00:00<00:17, 34.2MB/s]
#   3%|▎         | 15.7M/614M [00:00<00:16, 36.3MB/s]
#   3%|▎         | 19.4M/614M [00:00<00:16, 36.4MB/s]
#   4%|▍         | 23.1M/614M [00:00<00:16, 35.4MB/s]
#   4%|▍         | 26.7M/614M [00:00<00:16, 34.7MB/s]
# ...

# %%
os.makedirs('JS_Dataset',exist_ok=True)
with py7zr.SevenZipFile('valid_tune.7z', mode='r') as z:
    z.extractall('JS_Dataset')

# %%
/home/ubuntu/VALL-E-X-Trainer-by-CustomData/models/vallex.py:853: UserWarning: An output with one or more elements was resized since it had shape [770, 770], which does not match the required output shape [112, 770, 770]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at ../aten/src/ATen/native/Resize.cpp:28.)
  xy_attn_mask = xy_attn_mask.logical_or(_xy_padding_mask)
